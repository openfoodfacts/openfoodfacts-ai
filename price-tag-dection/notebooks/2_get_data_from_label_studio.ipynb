# %%
import os

# %%
data_path = "/Users/baslad01/data_dump/openfoodfacts/yolo"
project_id = 56
project_path = "/Users/baslad01/PycharmProjects/openfoodfacts-ai/ml_utils/ml_utils_cli"
API_KEY = os.getenv("LABEL_STUDIO_KEY")

# %%
# Remove the data folder is it exists
if os.path.exists(data_path):
    os.system(f"rm -rf {data_path}/data")

# Export the data using the command line
command = f"${{CONDA_PREFIX}}/bin/python3 {project_path}/main.py datasets export --project-id {project_id} --from ls --to ultralytics --output-dir {data_path} --label-names 'product,price-tag' --api-key {API_KEY}"
# Run the command
# !{command}
# Out:
# 2024-11-16 06:28:03,847 :: INFO :: PyTorch version 2.5.1 available.
# 2024-11-16 06:28:04,433 :: INFO :: Project ID: 56, category names: ['product', 'price-tag']
# 2024-11-16 06:28:05,288 :: INFO :: HTTP Request: GET https://annotate.openfoodfacts.org/api/tasks/?fields=all&project=56&page=1 "HTTP/1.1 200 OK"
# tasks: 0it [00:00, ?it/s]2024-11-16 06:28:05,363 :: WARNING :: Split information not found, assigning randomly. To avoid this, set the `split` field in the task data.
# tasks: 99it [00:21,  4.98it/s]2024-11-16 06:28:28,098 :: INFO :: HTTP Request: GET https://annotate.openfoodfacts.org/api/tasks/?fields=all&project=56&page=2 "HTTP/1.1 200 OK"
# tasks: 199it [00:37,  9.71it/s]2024-11-16 06:28:43,482 :: INFO :: HTTP Request: GET https://annotate.openfoodfacts.org/api/tasks/?fields=all&project=56&page=3 "HTTP/1.1 200 OK"
# tasks: 276it [00:40, 47.73it/s]2024-11-16 06:28:46,326 :: INFO :: HTTP Request: GET https://annotate.openfoodfacts.org/api/tasks/?fields=all&project=56&page=4 "HTTP/1.1 200 OK"
# tasks: 369it [00:42, 52.24it/s]2024-11-16 06:28:48,581 :: INFO :: HTTP Request: GET https://annotate.openfoodfacts.org/api/tasks/?fields=all&project=56&page=5 "HTTP/1.1 200 OK"
# tasks: 493it [00:45, 35.55it/s]2024-11-16 06:28:51,546 :: INFO :: HTTP Request: GET https://annotate.openfoodfacts.org/api/tasks/?fields=all&project=56&page=6 "HTTP/1.1 200 OK"
# tasks: 560it [00:47, 33.70it/s]2024-11-16 06:28:53,622 :: INFO :: HTTP Request: GET https://annotate.openfoodfacts.org/api/tasks/?fields=all&project=56&page=7 "HTTP/1.1 200 OK"
# tasks: 687it [00:51, 35.67it/s]2024-11-16 06:28:57,280 :: INFO :: HTTP Request: GET https://annotate.openfoodfacts.org/api/tasks/?fields=all&project=56&page=8 "HTTP/1.1 200 OK"
# tasks: 769it [00:54, 26.83it/s]2024-11-16 06:29:00,148 :: INFO :: HTTP Request: GET https://annotate.openfoodfacts.org/api/tasks/?fields=all&project=56&page=9 "HTTP/1.1 200 OK"
# tasks: 884it [00:58, 32.99it/s]2024-11-16 06:29:04,348 :: INFO :: HTTP Request: GET https://annotate.openfoodfacts.org/api/tasks/?fields=all&project=56&page=10 "HTTP/1.1 200 OK"
# tasks: 946it [00:59, 57.64it/s]2024-11-16 06:29:05,429 :: INFO :: HTTP Request: GET https://annotate.openfoodfacts.org/api/tasks/?fields=all&project=56&page=11 "HTTP/1.1 200 OK"
# tasks: 1093it [01:01, 59.26it/s]2024-11-16 06:29:07,934 :: INFO :: HTTP Request: GET https://annotate.openfoodfacts.org/api/tasks/?fields=all&project=56&page=12 "HTTP/1.1 200 OK"
# tasks: 1182it [01:03, 61.17it/s]2024-11-16 06:29:09,571 :: INFO :: HTTP Request: GET https://annotate.openfoodfacts.org/api/tasks/?fields=all&project=56&page=13 "HTTP/1.1 200 OK"
# tasks: 1229it [01:05, 38.80it/s]2024-11-16 06:29:11,105 :: INFO :: HTTP Request: GET https://annotate.openfoodfacts.org/api/tasks/?fields=all&project=56&page=14 "HTTP/1.1 200 OK"
# tasks: 1386it [01:07, 58.01it/s]2024-11-16 06:29:13,665 :: INFO :: HTTP Request: GET https://annotate.openfoodfacts.org/api/tasks/?fields=all&project=56&page=15 "HTTP/1.1 200 OK"
# tasks: 1474it [01:09, 63.61it/s]2024-11-16 06:29:15,303 :: INFO :: HTTP Request: GET https://annotate.openfoodfacts.org/api/tasks/?fields=all&project=56&page=16 "HTTP/1.1 200 OK"
# tasks: 1581it [01:10, 83.08it/s]2024-11-16 06:29:16,996 :: INFO :: HTTP Request: GET https://annotate.openfoodfacts.org/api/tasks/?fields=all&project=56&page=17 "HTTP/1.1 200 OK"
# tasks: 1675it [01:12, 51.89it/s]2024-11-16 06:29:18,906 :: INFO :: HTTP Request: GET https://annotate.openfoodfacts.org/api/tasks/?fields=all&project=56&page=18 "HTTP/1.1 200 OK"
# tasks: 1797it [01:14, 73.54it/s]2024-11-16 06:29:20,709 :: INFO :: HTTP Request: GET https://annotate.openfoodfacts.org/api/tasks/?fields=all&project=56&page=19 "HTTP/1.1 200 OK"
# tasks: 1886it [01:17, 44.16it/s]2024-11-16 06:29:23,392 :: INFO :: HTTP Request: GET https://annotate.openfoodfacts.org/api/tasks/?fields=all&project=56&page=20 "HTTP/1.1 200 OK"
# tasks: 1991it [01:20, 45.93it/s]2024-11-16 06:29:26,365 :: INFO :: HTTP Request: GET https://annotate.openfoodfacts.org/api/tasks/?fields=all&project=56&page=21 "HTTP/1.1 200 OK"
# tasks: 2034it [01:21, 43.92it/s]2024-11-16 06:29:27,491 :: INFO :: HTTP Request: GET https://annotate.openfoodfacts.org/api/tasks/?fields=all&project=56&page
:: INFO :: HTTP Request: GET https://annotate.openfoodfacts.org/api/tasks/?fields=all&project=56&page=79 "HTTP/1.1 200 OK"
# tasks: 7825it [03:34, 31.35it/s]2024-11-16 06:31:40,810 :: INFO :: HTTP Request: GET https://annotate.openfoodfacts.org/api/tasks/?fields=all&project=56&page=80 "HTTP/1.1 200 OK"
# tasks: 7994it [03:36, 69.73it/s]2024-11-16 06:31:42,557 :: INFO :: HTTP Request: GET https://annotate.openfoodfacts.org/api/tasks/?fields=all&project=56&page=81 "HTTP/1.1 200 OK"
# tasks: 8095it [03:39, 59.06it/s]2024-11-16 06:31:45,119 :: INFO :: HTTP Request: GET https://annotate.openfoodfacts.org/api/tasks/?fields=all&project=56&page=82 "HTTP/1.1 200 OK"
# tasks: 8174it [03:41, 47.18it/s]2024-11-16 06:31:47,269 :: INFO :: HTTP Request: GET https://annotate.openfoodfacts.org/api/tasks/?fields=all&project=56&page=83 "HTTP/1.1 200 OK"
# tasks: 8294it [03:44, 29.96it/s]2024-11-16 06:31:50,851 :: INFO :: HTTP Request: GET https://annotate.openfoodfacts.org/api/tasks/?fields=all&project=56&page=84 "HTTP/1.1 200 OK"
# tasks: 8398it [03:46, 80.17it/s]2024-11-16 06:31:52,698 :: INFO :: HTTP Request: GET https://annotate.openfoodfacts.org/api/tasks/?fields=all&project=56&page=85 "HTTP/1.1 200 OK"
# tasks: 8429it [03:48, 32.58it/s]2024-11-16 06:31:55,153 :: INFO :: HTTP Request: GET https://annotate.openfoodfacts.org/api/tasks/?fields=all&project=56&page=86 "HTTP/1.1 200 OK"
# tasks: 8592it [03:50, 87.67it/s]2024-11-16 06:31:56,232 :: INFO :: HTTP Request: GET https://annotate.openfoodfacts.org/api/tasks/?fields=all&project=56&page=87 "HTTP/1.1 200 OK"
# tasks: 8680it [03:52, 42.55it/s]2024-11-16 06:31:58,638 :: INFO :: HTTP Request: GET https://annotate.openfoodfacts.org/api/tasks/?fields=all&project=56&page=88 "HTTP/1.1 200 OK"
# tasks: 8716it [03:53, 40.19it/s]2024-11-16 06:31:59,556 :: INFO :: HTTP Request: GET https://annotate.openfoodfacts.org/api/tasks/?fields=all&project=56&page=89 "HTTP/1.1 200 OK"
# tasks: 8840it [03:55, 47.58it/s]2024-11-16 06:32:01,501 :: INFO :: HTTP Request: GET https://annotate.openfoodfacts.org/api/tasks/?fields=all&project=56&page=90 "HTTP/1.1 200 OK"
# tasks: 8979it [03:57, 58.31it/s]2024-11-16 06:32:03,550 :: INFO :: HTTP Request: GET https://annotate.openfoodfacts.org/api/tasks/?fields=all&project=56&page=91 "HTTP/1.1 200 OK"
# tasks: 9092it [03:59, 51.10it/s]2024-11-16 06:32:05,807 :: INFO :: HTTP Request: GET https://annotate.openfoodfacts.org/api/tasks/?fields=all&project=56&page=92 "HTTP/1.1 200 OK"
# tasks: 9188it [04:02, 45.24it/s]2024-11-16 06:32:08,262 :: INFO :: HTTP Request: GET https://annotate.openfoodfacts.org/api/tasks/?fields=all&project=56&page=93 "HTTP/1.1 200 OK"
# tasks: 9300it [04:18,  3.37it/s]2024-11-16 06:32:24,232 :: INFO :: HTTP Request: GET https://annotate.openfoodfacts.org/api/tasks/?fields=all&project=56&page=94 "HTTP/1.1 200 OK"
# tasks: 9400it [04:47,  3.23it/s]2024-11-16 06:32:53,624 :: INFO :: HTTP Request: GET https://annotate.openfoodfacts.org/api/tasks/?fields=all&project=56&page=95 "HTTP/1.1 200 OK"
# tasks: 9499it [05:41,  2.92it/s]2024-11-16 06:33:47,191 :: INFO :: HTTP Request: GET https://annotate.openfoodfacts.org/api/tasks/?fields=all&project=56&page=96 "HTTP/1.1 200 OK"
# tasks: 9517it [05:49, 27.23it/s]
# ╭───────────────────── Traceback (most recent call last) ──────────────────────╮
# │ /opt/homebrew/Caskroom/miniforge/base/envs/ml-cli/lib/python3.12/site-packag │
# │ es/urllib3/connection.py:199 in _new_conn                                    │
# │                                                                              │
# │    196 │   │   :return: New socket connection.                               │
# │    197 │   │   """                                                           │
# │    198 │   │   try:                                                          │
# │ ❱  199 │   │   │   sock = connection.create_connection(                      │
# │    200 │   │   │   │   (self._dns_host, self.port),                          │
# │    201 │   │   │   │   self.timeout,                                         │
# │    202 │   │   │   │   source_address=self.source_address,                   │
# │                                                                              │
# │ /opt/homebrew/Caskroom/miniforge/base/envs/ml-cli/lib/python3.12/site-packag │
# │ es/urllib3/util/connection.py:85 in create_connection                        │
# │                                                                              │
# │    82 │                                                                      │
# │    83 │   if err is not None:                                                │
# │    84 │   │   try:                                                           │
# │ ❱  85 │   │   │   raise err                                                  │
# │    86 │   │   finally:                                                       │
# │    87 │   │   │   # Break explicitly a reference cycle                       │
# │    88 │   │   │   err = None                                                 │
# │                                                                              │
# │ /opt/homebrew/Caskroom/miniforge/base/envs/ml-cli/lib/python3.12/site-packag │
# │ es/urllib3/util/connection.py:73 in create_connection                        │
# │                                                                              │
# │    70 │   │   │   │   sock.settimeout(timeout)                               │
# │    71 │   │   │   if source_address:                                         │
# │    72 │   │   │   │   sock.bind(source_address)                              │
# │ ❱  73 │   │   │   sock.connect(sa)                                           │
# │    74 │   │   │   # Break explicitly a reference cycle                       │
# │    75 │   │   │   err = None                                                 │
# │    76 │   │   │   return sock                                                │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# OSError: [Errno 12] Cannot allocate memory
#
# The above exception was the direct cause of the following exception:
#
# ╭───────────────────── Traceback (most recent call last) ──────────────────────╮
# │ /opt/homebrew/Caskroom/miniforge/base/envs/ml-cli/lib/python3.12/site-packag │
# │ es/urllib3/connectionpool.py:789 in urlopen                                  │
# │                                                                              │
# │    786 │   │   │   response_conn = conn if not release_conn else None        │
# │    787 │   │   │                                                             │
# │    788 │   │   │   # Make the request on the HTTPConnection object           │
# │ ❱  789 │   │   │   response = self._make_request(                            │
# │    790 │   │   │   │   conn,                                                 │
# │    791 │   │   │   │   method,                                               │
# │    792 │   │   │   │   url,                                                  │
# │                                                                              │
# │ /opt/homebrew/Caskroom/miniforge/base/envs/ml-cli/lib/python3.12/site-packag │
# │ es/urllib3/connectionpool.py:490 in _make_request                            │
# │                                                                              │
# │    487 │   │   │   │   new_e, (OSError, NewConnectionError, TimeoutError, SS │
# │    488 │   │   │   ) and (conn and conn.proxy and not conn.has_connected_to_ │
# │    489 │   │   │   │   new_e = _wrap_proxy_error(new_e, conn.proxy.scheme)   │
# │ ❱  490 │   │   │   raise new_e                                               │
# │    491 │   │                                                                 │
# │    492 │   │   # conn.request() calls http.client.*.request, not the method  │
# │    493 │   │   # urllib3.request. It also calls makefile (recv) on the socke │
# │                                                                              │
# │ /opt/homebrew/Caskroom/miniforge/base/envs/ml-cli/lib/python3.12/site-packag │
# │ es/urllib3/connectionpool.py:466 in _make_request                            │
# │                                                                              │
# │    463 │   │   try:                                                          │
# │    464 │   │   │   # Trigger any extra validation we need to do.             │
# │    465 │   │   │   try:                                                      │
# │ ❱  466 │   │   │   │   self._validate_conn(conn)                             │
# │    467 │   │   │   except (SocketTimeout, BaseSSLError) as e:                │
# │    468 │   │   │   │   self._raise_timeout(err=e, url=url, timeout_value=con │
# │    469 │   │   │   │   raise                                                 │
# │                                                                              │
# │ /opt/homebrew/Caskroom/miniforge/base/envs/ml-cli/lib/python3.12/site-packag │
# │ es/urllib3/connectionpool.py:1095 in _validate_conn                          │
# │                                                                              │
# │   1092 │   │                                                                 │
# │   1093 │   │   # Force connect early to allow us to validate the connection. │
# │   1094 │   │   if conn.is_closed:                                            │
# │ ❱ 1095 │   │   │   conn.connect()                                            │
# │   1096 │   │                                                                 │
# │   1097 │   │   # TODO revise this, see https://github.com/urllib3/urllib3/is │
# │   1098 │   │   if not conn.is_verified and not conn.proxy_is_verified:       │
# │                                                                              │
# │ /opt/homebrew/Caskroom/miniforge/base/envs/ml-cli/lib/python3.12/site-packag │
# │ es/urllib3/connection.py:693 in connect                                      │
# │                                                                              │
# │    690 │   │                                                                 │
# │    691 │   │   try:                                                          │
# │    692 │   │   │   sock: socket.socket | ssl.SSLSocket                       │
# │ ❱  693 │   │   │   self.sock = sock = self._new_conn()                       │
# │    694 │   │   │   server_hostname: str = self.host                          │
# │    695 │   │   │   tls_in_tls = False                                        │
# │    696                                                                       │
# │                                                                              │
# │ /opt/homebrew/Caskroom/miniforge/base/envs/ml-cli/lib/python3.12/site-packag │
# │ es/urllib3/connection.py:214 in _new_conn                                    │
# │                                                                              │
# │    211 │   │   │   ) from e                                                  │
# │    212 │   │                                                                 │
# │    213 │   │   except OSError as e:                                          │
# │ ❱  214 │   │   │   raise NewConnectionError(                                 │
# │    215 │   │   │   │   self, f"Failed to establish a new connection: {e}"    │
# │    216 │   │   │   ) from e                                                  │
# │    217                                                                       │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# NewConnectionError: <urllib3.connection.HTTPSConnection object at 0x174468cb0>:
# Failed to establish a new connection: [Errno 12] Cannot allocate memory
#
# The above exception was the direct cause of the following exception:
#
# ╭───────────────────── Traceback (most recent call last) ──────────────────────╮
# │ /opt/homebrew/Caskroom/miniforge/base/envs/ml-cli/lib/python3.12/site-packag │
# │ es/requests/adapters.py:667 in send                                          │
# │                                                                              │
# │   664 │   │   │   timeout = TimeoutSauce(connect=timeout, read=timeout)      │
# │   665 │   │                                                                  │
# │   666 │   │   try:                                                           │
# │ ❱ 667 │   │   │   resp = conn.urlopen(                                       │
# │   668 │   │   │   │   method=request.method,                                 │
# │   669 │   │   │   │   url=url,                                               │
# │   670 │   │   │   │   body=request.body,                                     │
# │                                                                              │
# │ /opt/homebrew/Caskroom/miniforge/base/envs/ml-cli/lib/python3.12/site-packag │
# │ es/urllib3/connectionpool.py:843 in urlopen                                  │
# │                                                                              │
# │    840 │   │   │   elif isinstance(new_e, (OSError, HTTPException)):         │
# │    841 │   │   │   │   new_e = ProtocolError("Connection aborted.", new_e)   │
# │    842 │   │   │                                                             │
# │ ❱  843 │   │   │   retries = retries.increment(                              │
# │    844 │   │   │   │   method, url, error=new_e, _pool=self, _stacktrace=sys │
# │    845 │   │   │   )                                                         │
# │    846 │   │   │   retries.sleep()                                           │
# │                                                                              │
# │ /opt/homebrew/Caskroom/miniforge/base/envs/ml-cli/lib/python3.12/site-packag │
# │ es/urllib3/util/retry.py:519 in increment                                    │
# │                                                                              │
# │   516 │   │                                                                  │
# │   517 │   │   if new_retry.is_exhausted():                                   │
# │   518 │   │   │   reason = error or ResponseError(cause)                     │
# │ ❱ 519 │   │   │   raise MaxRetryError(_pool, url, reason) from reason  # typ │
# │   520 │   │                                                                  │
# │   521 │   │   log.debug("Incremented Retry for (url='%s'): %r", url, new_ret │
# │   522                                                                        │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# MaxRetryError: HTTPSConnectionPool(host='prices.openfoodfacts.org', port=443):
# Max retries exceeded with url: /img/0008/Su9ade6Bfv.webp (Caused by
# NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x174468cb0>:
# Failed to establish a new connection: [Errno 12] Cannot allocate memory'))
#
# During handling of the above exception, another exception occurred:
#
# ╭───────────────────── Traceback (most recent call last) ──────────────────────╮
# │ /opt/homebrew/Caskroom/miniforge/base/envs/ml-cli/lib/python3.12/site-packag │
# │ es/openfoodfacts/utils.py:293 in get_asset_from_url                          │
# │                                                                              │
# │   290 │   │   if session:                                                    │
# │   291 │   │   │   r = session.get(asset_url, auth=auth)                      │
# │   292 │   │   else:                                                          │
# │ ❱ 293 │   │   │   r = requests.get(asset_url, auth=auth)                     │
# │   294 │   except (                                                           │
# │   295 │   │   requests.exceptions.ConnectionError,                           │
# │   296 │   │   requests.exceptions.SSLError,                                  │
# │                                                                              │
# │ /opt/homebrew/Caskroom/miniforge/base/envs/ml-cli/lib/python3.12/site-packag │
# │ es/requests/api.py:73 in get                                                 │
# │                                                                              │
# │    70 │   :rtype: requests.Response                                          │
# │    71 │   """                                                                │
# │    72 │                                                                      │
# │ ❱  73 │   return request("get", url, params=params, **kwargs)                │
# │    74                                                                        │
# │    75                                                                        │
# │    76 def options(url, **kwargs):                                            │
# │                                                                              │
# │ /opt/homebrew/Caskroom/miniforge/base/envs/ml-cli/lib/python3.12/site-packag │
# │ es/requests/api.py:59 in request                                             │
# │                                                                              │
# │    56 │   # avoid leaving sockets open which can trigger a ResourceWarning i │
# │    57 │   # cases, and look like a memory leak in others.                    │
# │    58 │   with sessions.Session() as session:                                │
# │ ❱  59 │   │   return session.request(method=method, url=url, **kwargs)       │
# │    60                                                                        │
# │    61                                                                        │
# │    62 def get(url, params=None, **kwargs):                                   │
# │                                                                              │
# │ /opt/homebrew/Caskroom/miniforge/base/envs/ml-cli/lib/python3.12/site-packag │
# │ es/requests/sessions.py:589 in request                                       │
# │                                                                              │
# │   586 │   │   │   "allow_redirects": allow_redirects,                        │
# │   587 │   │   }                                                              │
# │   588 │   │   send_kwargs.update(settings)                                   │
# │ ❱ 589 │   │   resp = self.send(prep, **send_kwargs)                          │
# │   590 │   │                                                                  │
# │   591 │   │   return resp                                                    │
# │   592                                                                        │
# │                                                                              │
# │ /opt/homebrew/Caskroom/miniforge/base/envs/ml-cli/lib/python3.12/site-packag │
# │ es/requests/sessions.py:703 in send                                          │
# │                                                                              │
# │   700 │   │   start = preferred_clock()                                      │
# │   701 │   │                                                                  │
# │   702 │   │   # Send the request                                             │
# │ ❱ 703 │   │   r = adapter.send(request, **kwargs)                            │
# │   704 │   │                                                                  │
# │   705 │   │   # Total elapsed time of the request (approximately)            │
# │   706 │   │   elapsed = preferred_clock() - start                            │
# │                                                                              │
# │ /opt/homebrew/Caskroom/miniforge/base/envs/ml-cli/lib/python3.12/site-packag │
# │ es/requests/adapters.py:700 in send                                          │
# │                                                                              │
# │   697 │   │   │   │   # This branch is for urllib3 v1.22 and later.          │
# │   698 │   │   │   │   raise SSLError(e, request=request)                     │
# │   699 │   │   │                                                              │
# │ ❱ 700 │   │   │   raise ConnectionError(e, request=request)                  │
# │   701 │   │                                                                  │
# │   702 │   │   except ClosedPoolError as e:                                   │
# │   703 │   │   │   raise ConnectionError(e, request=request)                  │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ConnectionError: HTTPSConnectionPool(host='prices.openfoodfacts.org', port=443):
# Max retries exceeded with url: /img/0008/Su9ade6Bfv.webp (Caused by
# NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x174468cb0>:
# Failed to establish a new connection: [Errno 12] Cannot allocate memory'))
#
# The above exception was the direct cause of the following exception:
#
# ╭───────────────────── Traceback (most recent call last) ──────────────────────╮
# │ /Users/baslad01/Library/CloudStorage/OneDrive-NielsenIQ/PycharmProjects/open │
# │ foodfacts-ai/ml_utils/ml_utils_cli/cli/apps/datasets.py:201 in export        │
# │                                                                              │
# │   198 │   │   │   │   ls, repo_id, label_names_list, typing.cast(int, projec │
# │   199 │   │   │   )                                                          │
# │   200 │   │   elif to == ExportDestination.ultralytics:                      │
# │ ❱ 201 │   │   │   export_from_ls_to_ultralytics(                             │
# │   202 │   │   │   │   ls,                                                    │
# │   203 │   │   │   │   typing.cast(Path, output_dir),                         │
# │   204 │   │   │   │   label_names_list,                                      │
# │                                                                              │
# │ /Users/baslad01/Library/CloudStorage/OneDrive-NielsenIQ/PycharmProjects/open │
# │ foodfacts-ai/ml_utils/ml_utils_cli/cli/export.py:164 in                      │
# │ export_from_ls_to_ultralytics                                                │
# │                                                                              │
# │   161 │   │   │   │   │   has_valid_annotation = True                        │
# │   162 │   │                                                                  │
# │   163 │   │   if has_valid_annotation:                                       │
# │ ❱ 164 │   │   │   download_output = download_image(image_url, return_bytes=T │
# │   165 │   │   │   if download_output is None:                                │
# │   166 │   │   │   │   logger.error("Failed to download image: %s", image_url │
# │   167 │   │   │   │   continue                                               │
# │                                                                              │
# │ /opt/homebrew/Caskroom/miniforge/base/envs/ml-cli/lib/python3.12/site-packag │
# │ es/openfoodfacts/images.py:228 in download_image                             │
# │                                                                              │
# │   225 │   │   │   image_url = generate_image_url(*image)                     │
# │   226 │                                                                      │
# │   227 │   logger.debug(f"Downloading image from {image_url}")                │
# │ ❱ 228 │   return get_image_from_url(                                         │
# │   229 │   │   image_url,                                                     │
# │   230 │   │   error_raise=error_raise,                                       │
# │   231 │   │   session=session,                                               │
# │                                                                              │
# │ /opt/homebrew/Caskroom/miniforge/base/envs/ml-cli/lib/python3.12/site-packag │
# │ es/openfoodfacts/utils.py:341 in get_image_from_url                          │
# │                                                                              │
# │   338 │   if not _pillow_available:                                          │
# │   339 │   │   raise ImportError("Pillow is required to load images")         │
# │   340 │                                                                      │
# │ ❱ 341 │   r = get_asset_from_url(image_url, error_raise, session)            │
# │   342 │   if r is None:                                                      │
# │   343 │   │   return None                                                    │
# │   344 │   content_bytes = r.content                                          │
# │                                                                              │
# │ /opt/homebrew/Caskroom/miniforge/base/envs/ml-cli/lib/python3.12/site-packag │
# │ es/openfoodfacts/utils.py:301 in get_asset_from_url                          │
# │                                                                              │
# │   298 │   ) as e:                                                            │
# │   299 │   │   error_message = "Cannot download %s"                           │
# │   300 │   │   if error_raise:                                                │
# │ ❱ 301 │   │   │   raise AssetLoadingException(error_message % asset_url) fro │
# │   302 │   │   logger.info(error_message, asset_url, exc_info=e)              │
# │   303 │   │   return None                                                    │
# │   304                                                                        │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# AssetLoadingException: Cannot download
# https://prices.openfoodfacts.org/img/0008/Su9ade6Bfv.webp

# %%
# Update the path data in data.yaml
# Open the file
with open(f"{data_path}/data.yaml", "r") as file:
    data = file.read()

# Update the path
data = data.replace(f"path: data", f"path: {data_path}/data", 1)

# Write the updated data
with open(f"{data_path}/data.yaml", "w") as file:
    file.write(data)
