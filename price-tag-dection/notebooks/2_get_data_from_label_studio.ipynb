# %%
import os

# %%
data_path = "/Users/baslad01/data_dump/openfoodfacts/yolo"
project_id = 56
project_path = "/Users/baslad01/PycharmProjects/openfoodfacts-ai/ml_utils/ml_utils_cli"
API_KEY = os.getenv("LABEL_STUDIO_KEY")

# %%
# Remove the data folder is it exists
if os.path.exists(data_path):
    os.system(f"rm -rf {data_path}/data")

# Export the data using the command line
command = f"${{CONDA_PREFIX}}/bin/python3 {project_path}/main.py datasets export --project-id {project_id} --from ls --to ultralytics --output-dir {data_path} --label-names 'product,price-tag' --api-key {API_KEY}"
# Run the command
# !{command}
# Out:
# 2024-11-17 06:29:16,080 :: INFO :: PyTorch version 2.5.1 available.
# 2024-11-17 06:29:16,596 :: INFO :: Project ID: 56, category names: ['product', 'price-tag']
# 2024-11-17 06:29:17,877 :: INFO :: HTTP Request: GET https://annotate.openfoodfacts.org/api/tasks/?fields=all&project=56&page=1 "HTTP/1.1 200 OK"
# tasks: 0it [00:00, ?it/s]2024-11-17 06:29:18,021 :: WARNING :: Split information not found, assigning randomly. To avoid this, set the `split` field in the task data.
# tasks: 100it [00:29,  2.43it/s]2024-11-17 06:29:48,523 :: INFO :: HTTP Request: GET https://annotate.openfoodfacts.org/api/tasks/?fields=all&project=56&page=2 "HTTP/1.1 200 OK"
# tasks: 199it [00:53,  9.06it/s]2024-11-17 06:30:12,238 :: INFO :: HTTP Request: GET https://annotate.openfoodfacts.org/api/tasks/?fields=all&project=56&page=3 "HTTP/1.1 200 OK"
# tasks: 276it [00:57, 37.91it/s]2024-11-17 06:30:16,041 :: INFO :: HTTP Request: GET https://annotate.openfoodfacts.org/api/tasks/?fields=all&project=56&page=4 "HTTP/1.1 200 OK"
# tasks: 397it [00:59, 55.42it/s]2024-11-17 06:30:18,513 :: INFO :: HTTP Request: GET https://annotate.openfoodfacts.org/api/tasks/?fields=all&project=56&page=5 "HTTP/1.1 200 OK"
# tasks: 493it [01:04, 24.34it/s]2024-11-17 06:30:23,400 :: INFO :: HTTP Request: GET https://annotate.openfoodfacts.org/api/tasks/?fields=all&project=56&page=6 "HTTP/1.1 200 OK"
# tasks: 560it [01:07, 24.07it/s]2024-11-17 06:30:25,954 :: INFO :: HTTP Request: GET https://annotate.openfoodfacts.org/api/tasks/?fields=all&project=56&page=7 "HTTP/1.1 200 OK"
# tasks: 687it [01:11, 27.82it/s]2024-11-17 06:30:30,378 :: INFO :: HTTP Request: GET https://annotate.openfoodfacts.org/api/tasks/?fields=all&project=56&page=8 "HTTP/1.1 200 OK"
# tasks: 769it [01:15, 22.48it/s]2024-11-17 06:30:33,960 :: INFO :: HTTP Request: GET https://annotate.openfoodfacts.org/api/tasks/?fields=all&project=56&page=9 "HTTP/1.1 200 OK"
# tasks: 884it [01:20, 28.06it/s]2024-11-17 06:30:39,639 :: INFO :: HTTP Request: GET https://annotate.openfoodfacts.org/api/tasks/?fields=all&project=56&page=10 "HTTP/1.1 200 OK"
# tasks: 985it [01:23, 46.10it/s]2024-11-17 06:30:41,843 :: INFO :: HTTP Request: GET https://annotate.openfoodfacts.org/api/tasks/?fields=all&project=56&page=11 "HTTP/1.1 200 OK"
# tasks: 1093it [01:26, 39.13it/s]2024-11-17 06:30:45,531 :: INFO :: HTTP Request: GET https://annotate.openfoodfacts.org/api/tasks/?fields=all&project=56&page=12 "HTTP/1.1 200 OK"
# tasks: 1192it [01:29, 34.65it/s]2024-11-17 06:30:48,092 :: INFO :: HTTP Request: GET https://annotate.openfoodfacts.org/api/tasks/?fields=all&project=56&page=13 "HTTP/1.1 200 OK"
# tasks: 1276it [01:32, 40.09it/s]2024-11-17 06:30:50,960 :: INFO :: HTTP Request: GET https://annotate.openfoodfacts.org/api/tasks/?fields=all&project=56&page=14 "HTTP/1.1 200 OK"
# tasks: 1398it [01:37, 25.17it/s]2024-11-17 06:30:56,284 :: INFO :: HTTP Request: GET https://annotate.openfoodfacts.org/api/tasks/?fields=all&project=56&page=15 "HTTP/1.1 200 OK"
# tasks: 1481it [01:41, 19.13it/s]2024-11-17 06:31:00,449 :: INFO :: HTTP Request: GET https://annotate.openfoodfacts.org/api/tasks/?fields=all&project=56&page=16 "HTTP/1.1 200 OK"
# tasks: 1584it [01:45, 30.46it/s]2024-11-17 06:31:04,476 :: INFO :: HTTP Request: GET https://annotate.openfoodfacts.org/api/tasks/?fields=all&project=56&page=17 "HTTP/1.1 200 OK"
# tasks: 1688it [01:50, 12.01it/s]2024-11-17 06:31:09,699 :: INFO :: HTTP Request: GET https://annotate.openfoodfacts.org/api/tasks/?fields=all&project=56&page=18 "HTTP/1.1 200 OK"
# tasks: 1800it [01:54, 32.41it/s]2024-11-17 06:31:13,080 :: INFO :: HTTP Request: GET https://annotate.openfoodfacts.org/api/tasks/?fields=all&project=56&page=19 "HTTP/1.1 200 OK"
# tasks: 1886it [01:57, 34.49it/s]2024-11-17 06:31:15,948 :: INFO :: HTTP Request: GET https://annotate.openfoodfacts.org/api/tasks/?fields=all&project=56&page
:: INFO :: HTTP Request: GET https://annotate.openfoodfacts.org/api/tasks/?fields=all&project=56&page=74 "HTTP/1.1 200 OK"
# tasks: 7343it [04:02, 37.68it/s]2024-11-17 06:33:21,183 :: INFO :: HTTP Request: GET https://annotate.openfoodfacts.org/api/tasks/?fields=all&project=56&page=75 "HTTP/1.1 200 OK"
# tasks: 7485it [04:06, 41.50it/s]2024-11-17 06:33:24,968 :: INFO :: HTTP Request: GET https://annotate.openfoodfacts.org/api/tasks/?fields=all&project=56&page=76 "HTTP/1.1 200 OK"
# tasks: 7595it [04:08, 66.69it/s]2024-11-17 06:33:27,120 :: INFO :: HTTP Request: GET https://annotate.openfoodfacts.org/api/tasks/?fields=all&project=56&page=77 "HTTP/1.1 200 OK"
# tasks: 7693it [04:11, 48.73it/s]2024-11-17 06:33:29,782 :: INFO :: HTTP Request: GET https://annotate.openfoodfacts.org/api/tasks/?fields=all&project=56&page=78 "HTTP/1.1 200 OK"
# tasks: 7782it [04:12, 72.98it/s]2024-11-17 06:33:31,116 :: INFO :: HTTP Request: GET https://annotate.openfoodfacts.org/api/tasks/?fields=all&project=56&page=79 "HTTP/1.1 200 OK"
# tasks: 7824it [04:14, 24.68it/s]2024-11-17 06:33:33,601 :: INFO :: HTTP Request: GET https://annotate.openfoodfacts.org/api/tasks/?fields=all&project=56&page=80 "HTTP/1.1 200 OK"
# tasks: 7994it [04:16, 60.25it/s]2024-11-17 06:33:35,523 :: INFO :: HTTP Request: GET https://annotate.openfoodfacts.org/api/tasks/?fields=all&project=56&page=81 "HTTP/1.1 200 OK"
# tasks: 8095it [04:19, 55.38it/s]2024-11-17 06:33:38,149 :: INFO :: HTTP Request: GET https://annotate.openfoodfacts.org/api/tasks/?fields=all&project=56&page=82 "HTTP/1.1 200 OK"
# tasks: 8174it [04:21, 46.14it/s]2024-11-17 06:33:40,364 :: INFO :: HTTP Request: GET https://annotate.openfoodfacts.org/api/tasks/?fields=all&project=56&page=83 "HTTP/1.1 200 OK"
# tasks: 8257it [04:23, 31.38it/s]
# ╭───────────────────── Traceback (most recent call last) ──────────────────────╮
# │ /opt/homebrew/Caskroom/miniforge/base/envs/ml-cli/lib/python3.12/site-packag │
# │ es/urllib3/connection.py:199 in _new_conn                                    │
# │                                                                              │
# │    196 │   │   :return: New socket connection.                               │
# │    197 │   │   """                                                           │
# │    198 │   │   try:                                                          │
# │ ❱  199 │   │   │   sock = connection.create_connection(                      │
# │    200 │   │   │   │   (self._dns_host, self.port),                          │
# │    201 │   │   │   │   self.timeout,                                         │
# │    202 │   │   │   │   source_address=self.source_address,                   │
# │                                                                              │
# │ /opt/homebrew/Caskroom/miniforge/base/envs/ml-cli/lib/python3.12/site-packag │
# │ es/urllib3/util/connection.py:85 in create_connection                        │
# │                                                                              │
# │    82 │                                                                      │
# │    83 │   if err is not None:                                                │
# │    84 │   │   try:                                                           │
# │ ❱  85 │   │   │   raise err                                                  │
# │    86 │   │   finally:                                                       │
# │    87 │   │   │   # Break explicitly a reference cycle                       │
# │    88 │   │   │   err = None                                                 │
# │                                                                              │
# │ /opt/homebrew/Caskroom/miniforge/base/envs/ml-cli/lib/python3.12/site-packag │
# │ es/urllib3/util/connection.py:73 in create_connection                        │
# │                                                                              │
# │    70 │   │   │   │   sock.settimeout(timeout)                               │
# │    71 │   │   │   if source_address:                                         │
# │    72 │   │   │   │   sock.bind(source_address)                              │
# │ ❱  73 │   │   │   sock.connect(sa)                                           │
# │    74 │   │   │   # Break explicitly a reference cycle                       │
# │    75 │   │   │   err = None                                                 │
# │    76 │   │   │   return sock                                                │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# OSError: [Errno 12] Cannot allocate memory
#
# The above exception was the direct cause of the following exception:
#
# ╭───────────────────── Traceback (most recent call last) ──────────────────────╮
# │ /opt/homebrew/Caskroom/miniforge/base/envs/ml-cli/lib/python3.12/site-packag │
# │ es/urllib3/connectionpool.py:789 in urlopen                                  │
# │                                                                              │
# │    786 │   │   │   response_conn = conn if not release_conn else None        │
# │    787 │   │   │                                                             │
# │    788 │   │   │   # Make the request on the HTTPConnection object           │
# │ ❱  789 │   │   │   response = self._make_request(                            │
# │    790 │   │   │   │   conn,                                                 │
# │    791 │   │   │   │   method,                                               │
# │    792 │   │   │   │   url,                                                  │
# │                                                                              │
# │ /opt/homebrew/Caskroom/miniforge/base/envs/ml-cli/lib/python3.12/site-packag │
# │ es/urllib3/connectionpool.py:490 in _make_request                            │
# │                                                                              │
# │    487 │   │   │   │   new_e, (OSError, NewConnectionError, TimeoutError, SS │
# │    488 │   │   │   ) and (conn and conn.proxy and not conn.has_connected_to_ │
# │    489 │   │   │   │   new_e = _wrap_proxy_error(new_e, conn.proxy.scheme)   │
# │ ❱  490 │   │   │   raise new_e                                               │
# │    491 │   │                                                                 │
# │    492 │   │   # conn.request() calls http.client.*.request, not the method  │
# │    493 │   │   # urllib3.request. It also calls makefile (recv) on the socke │
# │                                                                              │
# │ /opt/homebrew/Caskroom/miniforge/base/envs/ml-cli/lib/python3.12/site-packag │
# │ es/urllib3/connectionpool.py:466 in _make_request                            │
# │                                                                              │
# │    463 │   │   try:                                                          │
# │    464 │   │   │   # Trigger any extra validation we need to do.             │
# │    465 │   │   │   try:                                                      │
# │ ❱  466 │   │   │   │   self._validate_conn(conn)                             │
# │    467 │   │   │   except (SocketTimeout, BaseSSLError) as e:                │
# │    468 │   │   │   │   self._raise_timeout(err=e, url=url, timeout_value=con │
# │    469 │   │   │   │   raise                                                 │
# │                                                                              │
# │ /opt/homebrew/Caskroom/miniforge/base/envs/ml-cli/lib/python3.12/site-packag │
# │ es/urllib3/connectionpool.py:1095 in _validate_conn                          │
# │                                                                              │
# │   1092 │   │                                                                 │
# │   1093 │   │   # Force connect early to allow us to validate the connection. │
# │   1094 │   │   if conn.is_closed:                                            │
# │ ❱ 1095 │   │   │   conn.connect()                                            │
# │   1096 │   │                                                                 │
# │   1097 │   │   # TODO revise this, see https://github.com/urllib3/urllib3/is │
# │   1098 │   │   if not conn.is_verified and not conn.proxy_is_verified:       │
# │                                                                              │
# │ /opt/homebrew/Caskroom/miniforge/base/envs/ml-cli/lib/python3.12/site-packag │
# │ es/urllib3/connection.py:693 in connect                                      │
# │                                                                              │
# │    690 │   │                                                                 │
# │    691 │   │   try:                                                          │
# │    692 │   │   │   sock: socket.socket | ssl.SSLSocket                       │
# │ ❱  693 │   │   │   self.sock = sock = self._new_conn()                       │
# │    694 │   │   │   server_hostname: str = self.host                          │
# │    695 │   │   │   tls_in_tls = False                                        │
# │    696                                                                       │
# │                                                                              │
# │ /opt/homebrew/Caskroom/miniforge/base/envs/ml-cli/lib/python3.12/site-packag │
# │ es/urllib3/connection.py:214 in _new_conn                                    │
# │                                                                              │
# │    211 │   │   │   ) from e                                                  │
# │    212 │   │                                                                 │
# │    213 │   │   except OSError as e:                                          │
# │ ❱  214 │   │   │   raise NewConnectionError(                                 │
# │    215 │   │   │   │   self, f"Failed to establish a new connection: {e}"    │
# │    216 │   │   │   ) from e                                                  │
# │    217                                                                       │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# NewConnectionError: <urllib3.connection.HTTPSConnection object at 0x15ee8d340>:
# Failed to establish a new connection: [Errno 12] Cannot allocate memory
#
# The above exception was the direct cause of the following exception:
#
# ╭───────────────────── Traceback (most recent call last) ──────────────────────╮
# │ /opt/homebrew/Caskroom/miniforge/base/envs/ml-cli/lib/python3.12/site-packag │
# │ es/requests/adapters.py:667 in send                                          │
# │                                                                              │
# │   664 │   │   │   timeout = TimeoutSauce(connect=timeout, read=timeout)      │
# │   665 │   │                                                                  │
# │   666 │   │   try:                                                           │
# │ ❱ 667 │   │   │   resp = conn.urlopen(                                       │
# │   668 │   │   │   │   method=request.method,                                 │
# │   669 │   │   │   │   url=url,                                               │
# │   670 │   │   │   │   body=request.body,                                     │
# │                                                                              │
# │ /opt/homebrew/Caskroom/miniforge/base/envs/ml-cli/lib/python3.12/site-packag │
# │ es/urllib3/connectionpool.py:843 in urlopen                                  │
# │                                                                              │
# │    840 │   │   │   elif isinstance(new_e, (OSError, HTTPException)):         │
# │    841 │   │   │   │   new_e = ProtocolError("Connection aborted.", new_e)   │
# │    842 │   │   │                                                             │
# │ ❱  843 │   │   │   retries = retries.increment(                              │
# │    844 │   │   │   │   method, url, error=new_e, _pool=self, _stacktrace=sys │
# │    845 │   │   │   )                                                         │
# │    846 │   │   │   retries.sleep()                                           │
# │                                                                              │
# │ /opt/homebrew/Caskroom/miniforge/base/envs/ml-cli/lib/python3.12/site-packag │
# │ es/urllib3/util/retry.py:519 in increment                                    │
# │                                                                              │
# │   516 │   │                                                                  │
# │   517 │   │   if new_retry.is_exhausted():                                   │
# │   518 │   │   │   reason = error or ResponseError(cause)                     │
# │ ❱ 519 │   │   │   raise MaxRetryError(_pool, url, reason) from reason  # typ │
# │   520 │   │                                                                  │
# │   521 │   │   log.debug("Incremented Retry for (url='%s'): %r", url, new_ret │
# │   522                                                                        │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# MaxRetryError: HTTPSConnectionPool(host='prices.openfoodfacts.org', port=443):
# Max retries exceeded with url: /img/0006/FjMiQsoJyH.jpg (Caused by
# NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x15ee8d340>:
# Failed to establish a new connection: [Errno 12] Cannot allocate memory'))
#
# During handling of the above exception, another exception occurred:
#
# ╭───────────────────── Traceback (most recent call last) ──────────────────────╮
# │ /opt/homebrew/Caskroom/miniforge/base/envs/ml-cli/lib/python3.12/site-packag │
# │ es/openfoodfacts/utils.py:293 in get_asset_from_url                          │
# │                                                                              │
# │   290 │   │   if session:                                                    │
# │   291 │   │   │   r = session.get(asset_url, auth=auth)                      │
# │   292 │   │   else:                                                          │
# │ ❱ 293 │   │   │   r = requests.get(asset_url, auth=auth)                     │
# │   294 │   except (                                                           │
# │   295 │   │   requests.exceptions.ConnectionError,                           │
# │   296 │   │   requests.exceptions.SSLError,                                  │
# │                                                                              │
# │ /opt/homebrew/Caskroom/miniforge/base/envs/ml-cli/lib/python3.12/site-packag │
# │ es/requests/api.py:73 in get                                                 │
# │                                                                              │
# │    70 │   :rtype: requests.Response                                          │
# │    71 │   """                                                                │
# │    72 │                                                                      │
# │ ❱  73 │   return request("get", url, params=params, **kwargs)                │
# │    74                                                                        │
# │    75                                                                        │
# │    76 def options(url, **kwargs):                                            │
# │                                                                              │
# │ /opt/homebrew/Caskroom/miniforge/base/envs/ml-cli/lib/python3.12/site-packag │
# │ es/requests/api.py:59 in request                                             │
# │                                                                              │
# │    56 │   # avoid leaving sockets open which can trigger a ResourceWarning i │
# │    57 │   # cases, and look like a memory leak in others.                    │
# │    58 │   with sessions.Session() as session:                                │
# │ ❱  59 │   │   return session.request(method=method, url=url, **kwargs)       │
# │    60                                                                        │
# │    61                                                                        │
# │    62 def get(url, params=None, **kwargs):                                   │
# │                                                                              │
# │ /opt/homebrew/Caskroom/miniforge/base/envs/ml-cli/lib/python3.12/site-packag │
# │ es/requests/sessions.py:589 in request                                       │
# │                                                                              │
# │   586 │   │   │   "allow_redirects": allow_redirects,                        │
# │   587 │   │   }                                                              │
# │   588 │   │   send_kwargs.update(settings)                                   │
# │ ❱ 589 │   │   resp = self.send(prep, **send_kwargs)                          │
# │   590 │   │                                                                  │
# │   591 │   │   return resp                                                    │
# │   592                                                                        │
# │                                                                              │
# │ /opt/homebrew/Caskroom/miniforge/base/envs/ml-cli/lib/python3.12/site-packag │
# │ es/requests/sessions.py:703 in send                                          │
# │                                                                              │
# │   700 │   │   start = preferred_clock()                                      │
# │   701 │   │                                                                  │
# │   702 │   │   # Send the request                                             │
# │ ❱ 703 │   │   r = adapter.send(request, **kwargs)                            │
# │   704 │   │                                                                  │
# │   705 │   │   # Total elapsed time of the request (approximately)            │
# │   706 │   │   elapsed = preferred_clock() - start                            │
# │                                                                              │
# │ /opt/homebrew/Caskroom/miniforge/base/envs/ml-cli/lib/python3.12/site-packag │
# │ es/requests/adapters.py:700 in send                                          │
# │                                                                              │
# │   697 │   │   │   │   # This branch is for urllib3 v1.22 and later.          │
# │   698 │   │   │   │   raise SSLError(e, request=request)                     │
# │   699 │   │   │                                                              │
# │ ❱ 700 │   │   │   raise ConnectionError(e, request=request)                  │
# │   701 │   │                                                                  │
# │   702 │   │   except ClosedPoolError as e:                                   │
# │   703 │   │   │   raise ConnectionError(e, request=request)                  │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ConnectionError: HTTPSConnectionPool(host='prices.openfoodfacts.org', port=443):
# Max retries exceeded with url: /img/0006/FjMiQsoJyH.jpg (Caused by
# NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x15ee8d340>:
# Failed to establish a new connection: [Errno 12] Cannot allocate memory'))
#
# The above exception was the direct cause of the following exception:
#
# ╭───────────────────── Traceback (most recent call last) ──────────────────────╮
# │ /Users/baslad01/Library/CloudStorage/OneDrive-NielsenIQ/PycharmProjects/open │
# │ foodfacts-ai/ml_utils/ml_utils_cli/cli/apps/datasets.py:201 in export        │
# │                                                                              │
# │   198 │   │   │   │   ls, repo_id, label_names_list, typing.cast(int, projec │
# │   199 │   │   │   )                                                          │
# │   200 │   │   elif to == ExportDestination.ultralytics:                      │
# │ ❱ 201 │   │   │   export_from_ls_to_ultralytics(                             │
# │   202 │   │   │   │   ls,                                                    │
# │   203 │   │   │   │   typing.cast(Path, output_dir),                         │
# │   204 │   │   │   │   label_names_list,                                      │
# │                                                                              │
# │ /Users/baslad01/Library/CloudStorage/OneDrive-NielsenIQ/PycharmProjects/open │
# │ foodfacts-ai/ml_utils/ml_utils_cli/cli/export.py:164 in                      │
# │ export_from_ls_to_ultralytics                                                │
# │                                                                              │
# │   161 │   │   │   │   │   has_valid_annotation = True                        │
# │   162 │   │                                                                  │
# │   163 │   │   if has_valid_annotation:                                       │
# │ ❱ 164 │   │   │   download_output = download_image(image_url, return_bytes=T │
# │   165 │   │   │   if download_output is None:                                │
# │   166 │   │   │   │   logger.error("Failed to download image: %s", image_url │
# │   167 │   │   │   │   continue                                               │
# │                                                                              │
# │ /opt/homebrew/Caskroom/miniforge/base/envs/ml-cli/lib/python3.12/site-packag │
# │ es/openfoodfacts/images.py:228 in download_image                             │
# │                                                                              │
# │   225 │   │   │   image_url = generate_image_url(*image)                     │
# │   226 │                                                                      │
# │   227 │   logger.debug(f"Downloading image from {image_url}")                │
# │ ❱ 228 │   return get_image_from_url(                                         │
# │   229 │   │   image_url,                                                     │
# │   230 │   │   error_raise=error_raise,                                       │
# │   231 │   │   session=session,                                               │
# │                                                                              │
# │ /opt/homebrew/Caskroom/miniforge/base/envs/ml-cli/lib/python3.12/site-packag │
# │ es/openfoodfacts/utils.py:341 in get_image_from_url                          │
# │                                                                              │
# │   338 │   if not _pillow_available:                                          │
# │   339 │   │   raise ImportError("Pillow is required to load images")         │
# │   340 │                                                                      │
# │ ❱ 341 │   r = get_asset_from_url(image_url, error_raise, session)            │
# │   342 │   if r is None:                                                      │
# │   343 │   │   return None                                                    │
# │   344 │   content_bytes = r.content                                          │
# │                                                                              │
# │ /opt/homebrew/Caskroom/miniforge/base/envs/ml-cli/lib/python3.12/site-packag │
# │ es/openfoodfacts/utils.py:301 in get_asset_from_url                          │
# │                                                                              │
# │   298 │   ) as e:                                                            │
# │   299 │   │   error_message = "Cannot download %s"                           │
# │   300 │   │   if error_raise:                                                │
# │ ❱ 301 │   │   │   raise AssetLoadingException(error_message % asset_url) fro │
# │   302 │   │   logger.info(error_message, asset_url, exc_info=e)              │
# │   303 │   │   return None                                                    │
# │   304                                                                        │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# AssetLoadingException: Cannot download
# https://prices.openfoodfacts.org/img/0006/FjMiQsoJyH.jpg

# %%
# Update the path data in data.yaml
# Open the file
with open(f"{data_path}/data.yaml", "r") as file:
    data = file.read()

# Update the path
data = data.replace(f"path: data", f"path: {data_path}/data", 1)

# Write the updated data
with open(f"{data_path}/data.yaml", "w") as file:
    file.write(data)
