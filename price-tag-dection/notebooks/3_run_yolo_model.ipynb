# %%
from ultralytics import YOLO

# %%
data_path =  "/Users/baslad01/data_dump/openfoodfacts/yolo"

# Load a model
model = YOLO(f"{data_path}/yolo11n.pt")

# Train the model
train_results = model.train(
    data=f"{data_path}/data.yaml",  # path to dataset YAML
    epochs=1000,  # number of training epochs
    patience=50,  # early stopping patience
    dropout=0.1,  # dropout probability
    imgsz=640,  # training image size
    plots = True,  # create plots
    device="mps",  # device to run on, i.e. device=0 or device=0,1,2,3 or device=cpu
    project=f"{data_path}/model",  # save training results to project/name
)

# Evaluate model performance on the validation set
metrics = model.val()
# Out:
# New https://pypi.org/project/ultralytics/8.3.31 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.3.27 🚀 Python-3.12.7 torch-2.5.1 MPS (Apple M1 Pro)
# engine/trainer: task=detect, mode=train, model=/Users/baslad01/data_dump/openfoodfacts/yolo/yolo11n.pt, data=/Users/baslad01/data_dump/openfoodfacts/yolo/data.yaml, epochs=1000, time=None, patience=10, batch=16, imgsz=640, save=True, save_period=-1, cache=False, device=mps, workers=8, project=/Users/baslad01/data_dump/openfoodfacts/yolo/model, name=train5, exist_ok=False, pretrained=True, optimizer=auto, verbose=True, seed=0, deterministic=True, single_cls=False, rect=False, cos_lr=False, close_mosaic=10, resume=False, amp=True, fraction=1.0, profile=False, freeze=None, multi_scale=False, overlap_mask=True, mask_ratio=4, dropout=0.1, val=True, split=val, save_json=False, save_hybrid=False, conf=None, iou=0.7, max_det=300, half=False, dnn=False, plots=True, source=None, vid_stride=1, stream_buffer=False, visualize=False, augment=False, agnostic_nms=False, classes=None, retina_masks=False, embed=None, show=False, save_frames=False, save_txt=False, save_conf=False, save_crop=False, show_labels=True, show_conf=True, show_boxes=True, line_width=None, format=torchscript, keras=False, optimize=False, int8=False, dynamic=False, simplify=True, opset=None, workspace=4, nms=False, lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=7.5, cls=0.5, dfl=1.5, pose=12.0, kobj=1.0, label_smoothing=0.0, nbs=64, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, bgr=0.0, mosaic=1.0, mixup=0.0, copy_paste=0.0, copy_paste_mode=flip, auto_augment=randaugment, erasing=0.4, crop_fraction=1.0, cfg=None, tracker=botsort.yaml, save_dir=/Users/baslad01/data_dump/openfoodfacts/yolo/model/train5
# Overriding model.yaml nc=80 with nc=2
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      6640  ultralytics.nn.modules.block.C3k2            [32, 64, 1, False, 0.25]
#   3                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#   4                  -1  1     26080  ultralytics.nn.modules.block.C3k2            [64, 128, 1, False, 0.25]
#   5                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#   6                  -1  1     87040  ultralytics.nn.modules.block.C3k2            [128, 128, 1, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    346112  ultralytics.nn.modules.block.C3k2            [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.block.SPPF            [256, 256, 5]
#  10                  -1  1    249728  ultralytics.nn.modules.block.C2PSA           [256, 256, 1]
#  11                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  12             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  13                  -1  1    111296  ultralytics.nn.modules.block.C3k2            [384, 128, 1, False]
#  14                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  15             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  16                  -1  1     32096  ultralytics.nn.modules.block.C3k2            [256, 64, 1, False]
#  17                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  18            [-1, 13]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  19                  -1  1     86720  ultralytics.nn.modules.block.C3k2            [192, 128, 1, False]
#  20                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  21            [-1, 10]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  22                  -1  1    378880  ultralytics.nn.modules.block.C3k2            [384, 256, 1, True]
#  23        [16, 19, 22]  1    431062  ultralytics.nn.modules.head.Detect           [2, [64, 128, 256]]
# YOLO11n summary: 319 layers, 2,590,230 parameters, 2,590,214 gradients, 6.4 GFLOPs
#
# Transferred 448/499 items from pretrained weights
# Freezing layer 'model.23.dfl.conv.weight'
# train: Scanning /Users/baslad01/data_dump/openfoodfacts/yolo/data/labels/train... 206 images, 0 backgrounds, 4 corrupt: 100%|██████████| 206/206 [00:02<00:00, 99.58it/s]
# train: WARNING ⚠️ /Users/baslad01/data_dump/openfoodfacts/yolo/data/images/train/ByJGwB51bp.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.5136]
# train: WARNING ⚠️ /Users/baslad01/data_dump/openfoodfacts/yolo/data/images/train/P4NaXRglAW.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.4813]
# train: WARNING ⚠️ /Users/baslad01/data_dump/openfoodfacts/yolo/data/images/train/XzotST8ZsP.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.1149]
# train: WARNING ⚠️ /Users/baslad01/data_dump/openfoodfacts/yolo/data/images/train/rBklaZOEU6.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.5094]
# train: New cache created: /Users/baslad01/data_dump/openfoodfacts/yolo/data/labels/train.cache
# val: Scanning /Users/baslad01/data_dump/openfoodfacts/yolo/data/labels/val... 83 images, 0 backgrounds, 2 corrupt: 100%|██████████| 83/83 [00:00<00:00, 112.30it/s]
# val: WARNING ⚠️ /Users/baslad01/data_dump/openfoodfacts/yolo/data/images/val/P4NaXRglAW.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.4813]
# val: WARNING ⚠️ /Users/baslad01/data_dump/openfoodfacts/yolo/data/images/val/kC8NkgKPdA.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.4888]
# val: New cache created: /Users/baslad01/data_dump/openfoodfacts/yolo/data/labels/val.cache
# Plotting labels to /Users/baslad01/data_dump/openfoodfacts/yolo/model/train5/labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.001667, momentum=0.9) with parameter groups 81 weight(decay=0.0), 88 weight(decay=0.0005), 87 bias(decay=0.0)
# Image sizes 640 train, 640 val
# Using 0 dataloader workers
# Logging results to /Users/baslad01/data_dump/openfoodfacts/yolo/model/train5
# Starting training for 1000 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      1/1000      5.67G     0.9978      3.153      1.099         49        640: 100%|██████████| 13/13 [00:38<00:00,  2.98s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 3/3 [00:18<00:00,  6.29s/it]
#                    all         81        324     0.0116      0.577       0.15      0.108
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      2/1000      5.97G       1.05      2.036      1.026         36        640: 100%|██████████| 13/13 [00:27<00:00,  2.10s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 3/3 [00:11<00:00,  3.83s/it]
#                    all         81        324     0.0128      0.605      0.291      0.195
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      3/1000      4.73G      1.027      1.515      1.081         82        640: 100%|██████████| 13/13 [00:29<00:00,  2.27s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 3/3 [00:11<00:00,  3.88s/it]
#                    all         81        324       0.38     0.0587     0.0891     0.0591
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      4/1000      5.78G      1.028      1.355      1.078         55        640: 100%|██████████| 13/13 [00:29<00:00,  2.28s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 3/3 [00:11<00:00,  3.83s/it]
#                    all         81        324      0.483      0.121       0.14     0.0844
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      5/1000       5.8G       1.02      1.268      1.042         38        640: 100%|██████████| 13/13 [00:27<00:00,  2.15s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 3/3 [00:15<00:00,  5.11s/it]
#                    all         81        324      0.619      0.179      0.302      0.192
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      6/1000      5.76G     0.9977       1.21      1.063         45        640: 100%|██████████| 13/13 [00:35<00:00,  2.71s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95):  33%|███▎      | 1/3 [00:05<00:11,  5.55s/it]
# WARNING ⚠️ NMS time limit 3.600s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 3/3 [00:18<00:00,  6.29s/it]
#                    all         81        324      0.866      0.219      0.407      0.264
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      7/1000      5.95G       1.06      1.173      1.065        119        640: 100%|██████████| 13/13 [00:34<00:00,  2.65s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95):   0%|          | 0/3 [00:00<?, ?it/s]
# WARNING ⚠️ NMS time limit 3.600s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95):  33%|███▎      | 1/3 [00:05<00:11,  5.79s/it]
# WARNING ⚠️ NMS time limit 3.600s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95):  67%|██████▋   | 2/3 [00:13<00:06,  6.74s/it]
# WARNING ⚠️ NMS time limit 2.850s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 3/3 [00:19<00:00,  6.43s/it]
#                    all         81        324      0.544      0.273      0.346      0.225
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      8/1000      5.73G     0.9975      1.169      1.067         37        640: 100%|██████████| 13/13 [00:35<00:00,  2.72s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95):   0%|          | 0/3 [00:00<?, ?it/s]
# WARNING ⚠️ NMS time limit 3.600s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95):  33%|███▎      | 1/3 [00:05<00:11,  5.95s/it]
# WARNING ⚠️ NMS time limit 3.600s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95):  67%|██████▋   | 2/3 [00:13<00:06,  6.65s/it]
# WARNING ⚠️ NMS time limit 2.850s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 3/3 [00:19<00:00,  6.43s/it]
#                    all         81        324      0.313      0.312      0.188      0.136
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      9/1000      5.86G      1.083      1.206      1.101        107        640: 100%|██████████| 13/13 [00:35<00:00,  2.74s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95):   0%|          | 0/3 [00:00<?, ?it/s]
# WARNING ⚠️ NMS time limit 3.600s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95):  33%|███▎      | 1/3 [00:05<00:11,  5.89s/it]
# WARNING ⚠️ NMS time limit 3.600s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95):  67%|██████▋   | 2/3 [00:12<00:06,  6.59s/it]
# WARNING ⚠️ NMS time limit 2.850s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 3/3 [00:18<00:00,  6.24s/it]
#                    all         81        324      0.504      0.248      0.215      0.142
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     10/1000      5.82G       1.07      1.114      1.082        120        640: 100%|██████████| 13/13 [00:35<00:00,  2.72s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95):   0%|          | 0/3 [00:00<?, ?it/s]
# WARNING ⚠️ NMS time limit 3.600s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95):  33%|███▎      | 1/3 [00:05<00:11,  5.86s/it]
# WARNING ⚠️ NMS time limit 3.600s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95):  67%|██████▋   | 2/3 [00:13<00:06,  6.77s/it]
# WARNING ⚠️ NMS time limit 2.850s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 3/3 [00:19<00:00,  6.48s/it]
#                    all         81        324      0.433      0.238       0.18      0.103
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     11/1000       5.8G      1.024      1.055      1.032         52        640: 100%|██████████| 13/13 [00:36<00:00,  2.83s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95):   0%|          | 0/3 [00:00<?, ?it/s]
# WARNING ⚠️ NMS time limit 3.600s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95):  33%|███▎      | 1/3 [00:05<00:11,  5.62s/it]
# WARNING ⚠️ NMS time limit 3.600s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95):  67%|██████▋   | 2/3 [00:12<00:06,  6.65s/it]
# WARNING ⚠️ NMS time limit 2.850s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 3/3 [00:18<00:00,  6.17s/it]
#                    all         81        324      0.632      0.225      0.235      0.165
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     12/1000      5.88G      1.074      1.053      1.048         74        640: 100%|██████████| 13/13 [00:38<00:00,  2.99s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95):   0%|          | 0/3 [00:00<?, ?it/s]
# WARNING ⚠️ NMS time limit 3.600s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95):  33%|███▎      | 1/3 [00:06<00:12,  6.32s/it]
# WARNING ⚠️ NMS time limit 3.600s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95):  67%|██████▋   | 2/3 [00:13<00:06,  6.88s/it]
# WARNING ⚠️ NMS time limit 2.850s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 3/3 [00:20<00:00,  6.80s/it]
#                    all         81        324      0.559      0.176      0.164      0.115
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     13/1000       5.8G     0.9451     0.9966      1.033         49        640: 100%|██████████| 13/13 [00:40<00:00,  3.14s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95):   0%|          | 0/3 [00:00<?, ?it/s]
# WARNING ⚠️ NMS time limit 3.600s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95):  33%|███▎      | 1/3 [00:05<00:11,  5.85s/it]
# WARNING ⚠️ NMS time limit 3.600s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95):  67%|██████▋   | 2/3 [00:13<00:06,  6.95s/it]
# WARNING ⚠️ NMS time limit 2.850s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 3/3 [00:19<00:00,  6.42s/it]
#                    all         81        324      0.801      0.167      0.175      0.127
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     14/1000      4.82G     0.9392      1.012      1.026         33        640: 100%|██████████| 13/13 [00:42<00:00,  3.27s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95):   0%|          | 0/3 [00:00<?, ?it/s]
# WARNING ⚠️ NMS time limit 3.600s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95):  33%|███▎      | 1/3 [00:06<00:12,  6.05s/it]
# WARNING ⚠️ NMS time limit 3.600s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95):  67%|██████▋   | 2/3 [00:14<00:07,  7.20s/it]
# WARNING ⚠️ NMS time limit 2.850s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 3/3 [00:20<00:00,  6.84s/it]
#                    all         81        324       0.62      0.164      0.165      0.119
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     15/1000      5.89G     0.9931      0.967      1.019         56        640: 100%|██████████| 13/13 [00:45<00:00,  3.53s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95):   0%|          | 0/3 [00:00<?, ?it/s]
# WARNING ⚠️ NMS time limit 3.600s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95):  33%|███▎      | 1/3 [00:06<00:12,  6.05s/it]
# WARNING ⚠️ NMS time limit 3.600s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95):  67%|██████▋   | 2/3 [00:13<00:06,  6.70s/it]
# WARNING ⚠️ NMS time limit 2.850s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 3/3 [00:18<00:00,  6.29s/it]
#                    all         81        324      0.805       0.17      0.178      0.135
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     16/1000      4.87G     0.9069     0.9107      1.008         38        640: 100%|██████████| 13/13 [00:46<00:00,  3.56s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95):   0%|          | 0/3 [00:00<?, ?it/s]
# WARNING ⚠️ NMS time limit 3.600s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95):  33%|███▎      | 1/3 [00:10<00:20, 10.20s/it]
# WARNING ⚠️ NMS time limit 3.600s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95):  67%|██████▋   | 2/3 [00:18<00:09,  9.13s/it]
# WARNING ⚠️ NMS time limit 2.850s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 3/3 [00:24<00:00,  8.13s/it]
#                    all         81        324      0.757      0.176      0.171       0.13
# EarlyStopping: Training stopped early as no improvement observed in last 10 epochs. Best results observed at epoch 6, best model saved as best.pt.
# To update EarlyStopping(patience=10) pass a new patience value, i.e. `patience=300` or use `patience=0` to disable EarlyStopping.
# 16 epochs completed in 0.244 hours.
# Optimizer stripped from /Users/baslad01/data_dump/openfoodfacts/yolo/model/train5/weights/last.pt, 5.5MB
# Optimizer stripped from /Users/baslad01/data_dump/openfoodfacts/yolo/model/train5/weights/best.pt, 5.5MB
#
# Validating /Users/baslad01/data_dump/openfoodfacts/yolo/model/train5/weights/best.pt...
# Ultralytics 8.3.27 🚀 Python-3.12.7 torch-2.5.1 MPS (Apple M1 Pro)
# YOLO11n summary (fused): 238 layers, 2,582,542 parameters, 0 gradients, 6.3 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95):  33%|███▎      | 1/3 [00:06<00:12,  6.17s/it]
# WARNING ⚠️ NMS time limit 3.600s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 3/3 [00:21<00:00,  7.12s/it]
#                    all         81        324      0.845      0.236      0.467      0.304
#              price-tag         81        324      0.845      0.236      0.467      0.304
# Speed: 2.1ms preprocess, 69.3ms inference, 0.0ms loss, 87.0ms postprocess per image
# Results saved to /Users/baslad01/data_dump/openfoodfacts/yolo/model/train5
# Ultralytics 8.3.27 🚀 Python-3.12.7 torch-2.5.1 MPS (Apple M1 Pro)
# YOLO11n summary (fused): 238 layers, 2,582,542 parameters, 0 gradients, 6.3 GFLOPs
# val: Scanning /Users/baslad01/data_dump/openfoodfacts/yolo/data/labels/val.cache... 83 images, 0 backgrounds, 2 corrupt: 100%|██████████| 83/83 [00:00<?, ?it/s]
# val: WARNING ⚠️ /Users/baslad01/data_dump/openfoodfacts/yolo/data/images/val/P4NaXRglAW.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.4813]
# val: WARNING ⚠️ /Users/baslad01/data_dump/openfoodfacts/yolo/data/images/val/kC8NkgKPdA.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.4888]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95):   0%|          | 0/6 [00:00<?, ?it/s]
# WARNING ⚠️ NMS time limit 2.800s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95):  50%|█████     | 3/6 [00:20<00:20,  6.70s/it]
# WARNING ⚠️ NMS time limit 2.800s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 6/6 [00:37<00:00,  6.31s/it]
#                    all         81        324      0.872      0.231      0.488      0.315
#              price-tag         81        324      0.872      0.231      0.488      0.315
# Speed: 5.1ms preprocess, 275.5ms inference, 0.0ms loss, 100.3ms postprocess per image
# Results saved to /Users/baslad01/data_dump/openfoodfacts/yolo/model/train52

# %%
# Perform object detection on an image

image_test_list = [f"{data_path}/test/4xXuBb8u3E.jpg", f"{data_path}/test/test_image.jpg"]

results = model.predict(image_test_list, conf=0.1, save=True, project=f"{data_path}/test")  # or with a list of image paths
# results[0].show()
# Out:
# 0: 640x640 1 price-tag, 31.8ms
# 1: 640x640 (no detections), 31.8ms
# Speed: 2.4ms preprocess, 31.8ms inference, 6.5ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to /Users/baslad01/data_dump/openfoodfacts/yolo/test/train4

# %%
# Export model
path = model.export(format="onnx")
# Out:
# Ultralytics 8.3.27 🚀 Python-3.12.7 torch-2.5.1 CPU (Apple M1 Pro)
#
# PyTorch: starting from '/Users/baslad01/data_dump/openfoodfacts/yolo/model/train3/weights/best.pt' with input shape (1, 3, 640, 640) BCHW and output shape(s) (1, 6, 8400) (5.2 MB)
#
# ONNX: starting export with onnx 1.17.0 opset 19...
# ONNX: slimming with onnxslim 0.1.36...
# ONNX: export success ✅ 0.8s, saved as '/Users/baslad01/data_dump/openfoodfacts/yolo/model/train3/weights/best.onnx' (10.1 MB)
#
# Export complete (1.0s)
# Results saved to /Users/baslad01/data_dump/openfoodfacts/yolo/model/train3/weights
# Predict:         yolo predict task=detect model=/Users/baslad01/data_dump/openfoodfacts/yolo/model/train3/weights/best.onnx imgsz=640
# Validate:        yolo val task=detect model=/Users/baslad01/data_dump/openfoodfacts/yolo/model/train3/weights/best.onnx imgsz=640 data=/Users/baslad01/data_dump/openfoodfacts/yolo/data.yaml
# Visualize:       https://netron.app
