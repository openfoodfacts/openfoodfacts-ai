# %%
from ultralytics import YOLO

# %%
data_path =  "/Users/baslad01/data_dump/openfoodfacts/yolo"

# Load a model
model = YOLO(f"{data_path}/yolo11n.pt")

# Train the model
train_results = model.train(
    data=f"{data_path}/data.yaml",  # path to dataset YAML
    epochs=1000,  # number of training epochs
    patience=10,  # early stopping patience
    dropout=0.1,  # dropout probability
    imgsz=640,  # training image size
    plots = True,  # create plots
    device="mps",  # device to run on, i.e. device=0 or device=0,1,2,3 or device=cpu
    project=f"{data_path}/model",  # save training results to project/name
)

# Evaluate model performance on the validation set
metrics = model.val()
# Out:
# New https://pypi.org/project/ultralytics/8.3.29 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.3.27 🚀 Python-3.12.7 torch-2.5.1 MPS (Apple M1 Pro)
# engine/trainer: task=detect, mode=train, model=/Users/baslad01/data_dump/openfoodfacts/yolo/yolo11n.pt, data=/Users/baslad01/data_dump/openfoodfacts/yolo/data.yaml, epochs=1000, time=None, patience=10, batch=16, imgsz=640, save=True, save_period=-1, cache=False, device=mps, workers=8, project=/Users/baslad01/data_dump/openfoodfacts/yolo/model, name=train4, exist_ok=False, pretrained=True, optimizer=auto, verbose=True, seed=0, deterministic=True, single_cls=False, rect=False, cos_lr=False, close_mosaic=10, resume=False, amp=True, fraction=1.0, profile=False, freeze=None, multi_scale=False, overlap_mask=True, mask_ratio=4, dropout=0.1, val=True, split=val, save_json=False, save_hybrid=False, conf=None, iou=0.7, max_det=300, half=False, dnn=False, plots=True, source=None, vid_stride=1, stream_buffer=False, visualize=False, augment=False, agnostic_nms=False, classes=None, retina_masks=False, embed=None, show=False, save_frames=False, save_txt=False, save_conf=False, save_crop=False, show_labels=True, show_conf=True, show_boxes=True, line_width=None, format=torchscript, keras=False, optimize=False, int8=False, dynamic=False, simplify=True, opset=None, workspace=4, nms=False, lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=7.5, cls=0.5, dfl=1.5, pose=12.0, kobj=1.0, label_smoothing=0.0, nbs=64, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, bgr=0.0, mosaic=1.0, mixup=0.0, copy_paste=0.0, copy_paste_mode=flip, auto_augment=randaugment, erasing=0.4, crop_fraction=1.0, cfg=None, tracker=botsort.yaml, save_dir=/Users/baslad01/data_dump/openfoodfacts/yolo/model/train4
# Overriding model.yaml nc=80 with nc=2
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      6640  ultralytics.nn.modules.block.C3k2            [32, 64, 1, False, 0.25]
#   3                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#   4                  -1  1     26080  ultralytics.nn.modules.block.C3k2            [64, 128, 1, False, 0.25]
#   5                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#   6                  -1  1     87040  ultralytics.nn.modules.block.C3k2            [128, 128, 1, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    346112  ultralytics.nn.modules.block.C3k2            [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.block.SPPF            [256, 256, 5]
#  10                  -1  1    249728  ultralytics.nn.modules.block.C2PSA           [256, 256, 1]
#  11                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  12             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  13                  -1  1    111296  ultralytics.nn.modules.block.C3k2            [384, 128, 1, False]
#  14                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  15             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  16                  -1  1     32096  ultralytics.nn.modules.block.C3k2            [256, 64, 1, False]
#  17                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  18            [-1, 13]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  19                  -1  1     86720  ultralytics.nn.modules.block.C3k2            [192, 128, 1, False]
#  20                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  21            [-1, 10]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  22                  -1  1    378880  ultralytics.nn.modules.block.C3k2            [384, 256, 1, True]
#  23        [16, 19, 22]  1    431062  ultralytics.nn.modules.head.Detect           [2, [64, 128, 256]]
# YOLO11n summary: 319 layers, 2,590,230 parameters, 2,590,214 gradients, 6.4 GFLOPs
#
# Transferred 448/499 items from pretrained weights
# Freezing layer 'model.23.dfl.conv.weight'
# train: Scanning /Users/baslad01/data_dump/openfoodfacts/yolo/data/labels/train.cache... 150 images, 0 backgrounds, 4 corrupt: 100%|██████████| 150/150 [00:00<?, ?it/s]
# train: WARNING ⚠️ /Users/baslad01/data_dump/openfoodfacts/yolo/data/images/train/ByJGwB51bp.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.5136]
# train: WARNING ⚠️ /Users/baslad01/data_dump/openfoodfacts/yolo/data/images/train/P4NaXRglAW.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.4813]
# train: WARNING ⚠️ /Users/baslad01/data_dump/openfoodfacts/yolo/data/images/train/XzotST8ZsP.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.1149]
# train: WARNING ⚠️ /Users/baslad01/data_dump/openfoodfacts/yolo/data/images/train/rBklaZOEU6.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.5094]
# val: Scanning /Users/baslad01/data_dump/openfoodfacts/yolo/data/labels/val.cache... 52 images, 0 backgrounds, 1 corrupt: 100%|██████████| 52/52 [00:00<?, ?it/s]
# val: WARNING ⚠️ /Users/baslad01/data_dump/openfoodfacts/yolo/data/images/val/P4NaXRglAW.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.4813]
# Plotting labels to /Users/baslad01/data_dump/openfoodfacts/yolo/model/train4/labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.001667, momentum=0.9) with parameter groups 81 weight(decay=0.0), 88 weight(decay=0.0005), 87 bias(decay=0.0)
# Image sizes 640 train, 640 val
# Using 0 dataloader workers
# Logging results to /Users/baslad01/data_dump/openfoodfacts/yolo/model/train4
# Starting training for 1000 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      1/1000      6.14G      1.113      3.294      1.142         13        640: 100%|██████████| 10/10 [00:22<00:00,  2.20s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:05<00:00,  2.87s/it]
#                    all         51        152     0.0108      0.691      0.102     0.0613
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      2/1000      6.03G      1.043      2.468      1.036         11        640: 100%|██████████| 10/10 [00:11<00:00,  1.18s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:05<00:00,  2.80s/it]
#                    all         51        152     0.0143      0.908      0.275      0.189
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      3/1000      6.19G      1.002      1.592      1.027         17        640: 100%|██████████| 10/10 [00:11<00:00,  1.11s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:05<00:00,  2.79s/it]
#                    all         51        152     0.0137      0.776      0.335      0.217
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      4/1000      6.02G      1.105      1.385      1.024          8        640: 100%|██████████| 10/10 [00:10<00:00,  1.07s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:06<00:00,  3.32s/it]
#                    all         51        152      0.861     0.0408      0.388      0.274
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      5/1000      4.77G     0.9932      1.309       1.05         12        640: 100%|██████████| 10/10 [00:11<00:00,  1.13s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:05<00:00,  2.73s/it]
#                    all         51        152      0.602      0.112      0.303       0.21
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      6/1000      5.86G      1.022      1.287      1.056          7        640: 100%|██████████| 10/10 [00:11<00:00,  1.17s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:05<00:00,  2.92s/it]
#                    all         51        152      0.631       0.23      0.388      0.236
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      7/1000      6.17G       1.01      1.149       1.01         13        640: 100%|██████████| 10/10 [00:11<00:00,  1.14s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:05<00:00,  2.90s/it]
#                    all         51        152      0.664      0.287      0.505      0.349
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      8/1000      6.15G      1.064      1.154      1.032         15        640: 100%|██████████| 10/10 [00:10<00:00,  1.09s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:06<00:00,  3.04s/it]
#                    all         51        152      0.337      0.362      0.333      0.227
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      9/1000       4.8G      1.051      1.146      1.045         23        640: 100%|██████████| 10/10 [00:10<00:00,  1.07s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:09<00:00,  4.56s/it]
#                    all         51        152      0.303      0.388      0.346      0.222
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     10/1000      6.03G      1.019      1.149      1.067         10        640: 100%|██████████| 10/10 [00:10<00:00,  1.09s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:10<00:00,  5.40s/it]
#                    all         51        152      0.329      0.559      0.416      0.247
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     11/1000      5.92G      1.028      1.104      1.064         10        640: 100%|██████████| 10/10 [00:20<00:00,  2.02s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95):   0%|          | 0/2 [00:00<?, ?it/s]
# WARNING ⚠️ NMS time limit 3.600s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95):  50%|█████     | 1/2 [00:06<00:06,  6.94s/it]
# WARNING ⚠️ NMS time limit 2.950s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:12<00:00,  6.16s/it]
#                    all         51        152       0.29      0.172      0.106     0.0469
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     12/1000      6.02G      1.094      1.051      1.038          6        640: 100%|██████████| 10/10 [00:26<00:00,  2.61s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95):   0%|          | 0/2 [00:00<?, ?it/s]
# WARNING ⚠️ NMS time limit 3.600s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95):  50%|█████     | 1/2 [00:06<00:06,  6.90s/it]
# WARNING ⚠️ NMS time limit 2.950s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:12<00:00,  6.15s/it]
#                    all         51        152      0.607      0.204      0.189      0.112
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     13/1000      5.94G     0.9845       1.04      1.002         16        640: 100%|██████████| 10/10 [00:24<00:00,  2.40s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95):   0%|          | 0/2 [00:00<?, ?it/s]
# WARNING ⚠️ NMS time limit 3.600s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95):  50%|█████     | 1/2 [00:06<00:06,  6.93s/it]
# WARNING ⚠️ NMS time limit 2.950s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:12<00:00,  6.26s/it]
#                    all         51        152      0.294      0.184     0.0852     0.0497
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     14/1000      5.86G     0.9703      1.136       1.03          2        640: 100%|██████████| 10/10 [00:23<00:00,  2.35s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95):   0%|          | 0/2 [00:00<?, ?it/s]
# WARNING ⚠️ NMS time limit 3.600s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95):  50%|█████     | 1/2 [00:06<00:06,  6.76s/it]
# WARNING ⚠️ NMS time limit 2.950s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:12<00:00,  6.05s/it]
#                    all         51        152      0.343      0.164     0.0748     0.0572
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     15/1000         6G     0.9693      0.934     0.9919         11        640: 100%|██████████| 10/10 [00:26<00:00,  2.66s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95):   0%|          | 0/2 [00:00<?, ?it/s]
# WARNING ⚠️ NMS time limit 3.600s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95):  50%|█████     | 1/2 [00:06<00:06,  6.97s/it]
# WARNING ⚠️ NMS time limit 2.950s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:12<00:00,  6.26s/it]
#                    all         51        152      0.409      0.164     0.0859     0.0576
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     16/1000       4.8G     0.9556      1.005       1.02          4        640: 100%|██████████| 10/10 [00:26<00:00,  2.69s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95):   0%|          | 0/2 [00:00<?, ?it/s]
# WARNING ⚠️ NMS time limit 3.600s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95):  50%|█████     | 1/2 [00:06<00:06,  6.92s/it]
# WARNING ⚠️ NMS time limit 2.950s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:12<00:00,  6.35s/it]
#                    all         51        152      0.378      0.164      0.106     0.0824
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     17/1000      5.85G     0.9758     0.9557      1.027          7        640: 100%|██████████| 10/10 [00:24<00:00,  2.43s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95):   0%|          | 0/2 [00:00<?, ?it/s]
# WARNING ⚠️ NMS time limit 3.600s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95):  50%|█████     | 1/2 [00:06<00:06,  6.83s/it]
# WARNING ⚠️ NMS time limit 2.950s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:12<00:00,  6.12s/it]
#                    all         51        152       0.71      0.158       0.14      0.109
# EarlyStopping: Training stopped early as no improvement observed in last 10 epochs. Best results observed at epoch 7, best model saved as best.pt.
# To update EarlyStopping(patience=10) pass a new patience value, i.e. `patience=300` or use `patience=0` to disable EarlyStopping.
# 17 epochs completed in 0.128 hours.
# Optimizer stripped from /Users/baslad01/data_dump/openfoodfacts/yolo/model/train4/weights/last.pt, 5.5MB
# Optimizer stripped from /Users/baslad01/data_dump/openfoodfacts/yolo/model/train4/weights/best.pt, 5.5MB
#
# Validating /Users/baslad01/data_dump/openfoodfacts/yolo/model/train4/weights/best.pt...
# Ultralytics 8.3.27 🚀 Python-3.12.7 torch-2.5.1 MPS (Apple M1 Pro)
# YOLO11n summary (fused): 238 layers, 2,582,542 parameters, 0 gradients, 6.3 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:05<00:00,  2.56s/it]
#                    all         51        152      0.664      0.286      0.505      0.349
#              price-tag         51        152      0.664      0.286      0.505      0.349
# Speed: 1.9ms preprocess, 7.1ms inference, 0.0ms loss, 7.6ms postprocess per image
# Results saved to /Users/baslad01/data_dump/openfoodfacts/yolo/model/train4
# Ultralytics 8.3.27 🚀 Python-3.12.7 torch-2.5.1 MPS (Apple M1 Pro)
# YOLO11n summary (fused): 238 layers, 2,582,542 parameters, 0 gradients, 6.3 GFLOPs
# val: Scanning /Users/baslad01/data_dump/openfoodfacts/yolo/data/labels/val.cache... 52 images, 0 backgrounds, 1 corrupt: 100%|██████████| 52/52 [00:00<?, ?it/s]
# val: WARNING ⚠️ /Users/baslad01/data_dump/openfoodfacts/yolo/data/images/val/P4NaXRglAW.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.4813]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 4/4 [00:05<00:00,  1.27s/it]
#                    all         51        152      0.666      0.302      0.514       0.36
#              price-tag         51        152      0.666      0.302      0.514       0.36
# Speed: 1.9ms preprocess, 7.8ms inference, 0.0ms loss, 7.2ms postprocess per image
# Results saved to /Users/baslad01/data_dump/openfoodfacts/yolo/model/train42

# %%
# Perform object detection on an image

image_test_list = [f"{data_path}/test/4xXuBb8u3E.jpg", f"{data_path}/test/test_image.jpg"]

results = model.predict(image_test_list, conf=0.1, save=True, project=f"{data_path}/test")  # or with a list of image paths
# results[0].show()
# Out:
# 0: 640x640 1 price-tag, 31.8ms
# 1: 640x640 (no detections), 31.8ms
# Speed: 2.4ms preprocess, 31.8ms inference, 6.5ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to /Users/baslad01/data_dump/openfoodfacts/yolo/test/train4

# %%
# Export model
path = model.export(format="onnx")
# Out:
# Ultralytics 8.3.27 🚀 Python-3.12.7 torch-2.5.1 CPU (Apple M1 Pro)
#
# PyTorch: starting from '/Users/baslad01/data_dump/openfoodfacts/yolo/model/train3/weights/best.pt' with input shape (1, 3, 640, 640) BCHW and output shape(s) (1, 6, 8400) (5.2 MB)
#
# ONNX: starting export with onnx 1.17.0 opset 19...
# ONNX: slimming with onnxslim 0.1.36...
# ONNX: export success ✅ 0.8s, saved as '/Users/baslad01/data_dump/openfoodfacts/yolo/model/train3/weights/best.onnx' (10.1 MB)
#
# Export complete (1.0s)
# Results saved to /Users/baslad01/data_dump/openfoodfacts/yolo/model/train3/weights
# Predict:         yolo predict task=detect model=/Users/baslad01/data_dump/openfoodfacts/yolo/model/train3/weights/best.onnx imgsz=640
# Validate:        yolo val task=detect model=/Users/baslad01/data_dump/openfoodfacts/yolo/model/train3/weights/best.onnx imgsz=640 data=/Users/baslad01/data_dump/openfoodfacts/yolo/data.yaml
# Visualize:       https://netron.app
