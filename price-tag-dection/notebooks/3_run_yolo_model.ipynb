# %%
from ultralytics import YOLO

# %%
data_path =  "/Users/baslad01/data_dump/openfoodfacts/yolo"

# Load a model
model = YOLO(f"{data_path}/yolo11n.pt")

# Train the model
train_results = model.train(
    data=f"{data_path}/data.yaml",  # path to dataset YAML
    epochs=10,  # number of training epochs
    patience=3,  # early stopping patience
    dropout=0.1,  # dropout probability
    imgsz=640,  # training image size
    plots = True,  # create plots
    device="mps",  # device to run on, i.e. device=0 or device=0,1,2,3 or device=cpu
    project=f"{data_path}/model",  # save training results to project/name
)

# Evaluate model performance on the validation set
metrics = model.val()
# Out:
# New https://pypi.org/project/ultralytics/8.3.28 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.3.27 🚀 Python-3.12.7 torch-2.5.1 MPS (Apple M1 Pro)
# engine/trainer: task=detect, mode=train, model=/Users/baslad01/data_dump/openfoodfacts/yolo/yolo11n.pt, data=/Users/baslad01/data_dump/openfoodfacts/yolo/data.yaml, epochs=10, time=None, patience=3, batch=16, imgsz=640, save=True, save_period=-1, cache=False, device=mps, workers=8, project=/Users/baslad01/data_dump/openfoodfacts/yolo/model, name=train, exist_ok=False, pretrained=True, optimizer=auto, verbose=True, seed=0, deterministic=True, single_cls=False, rect=False, cos_lr=False, close_mosaic=10, resume=False, amp=True, fraction=1.0, profile=False, freeze=None, multi_scale=False, overlap_mask=True, mask_ratio=4, dropout=0.1, val=True, split=val, save_json=False, save_hybrid=False, conf=None, iou=0.7, max_det=300, half=False, dnn=False, plots=True, source=None, vid_stride=1, stream_buffer=False, visualize=False, augment=False, agnostic_nms=False, classes=None, retina_masks=False, embed=None, show=False, save_frames=False, save_txt=False, save_conf=False, save_crop=False, show_labels=True, show_conf=True, show_boxes=True, line_width=None, format=torchscript, keras=False, optimize=False, int8=False, dynamic=False, simplify=True, opset=None, workspace=4, nms=False, lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=7.5, cls=0.5, dfl=1.5, pose=12.0, kobj=1.0, label_smoothing=0.0, nbs=64, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, bgr=0.0, mosaic=1.0, mixup=0.0, copy_paste=0.0, copy_paste_mode=flip, auto_augment=randaugment, erasing=0.4, crop_fraction=1.0, cfg=None, tracker=botsort.yaml, save_dir=/Users/baslad01/data_dump/openfoodfacts/yolo/model/train
# Overriding model.yaml nc=80 with nc=2
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      6640  ultralytics.nn.modules.block.C3k2            [32, 64, 1, False, 0.25]
#   3                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#   4                  -1  1     26080  ultralytics.nn.modules.block.C3k2            [64, 128, 1, False, 0.25]
#   5                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#   6                  -1  1     87040  ultralytics.nn.modules.block.C3k2            [128, 128, 1, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    346112  ultralytics.nn.modules.block.C3k2            [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.block.SPPF            [256, 256, 5]
#  10                  -1  1    249728  ultralytics.nn.modules.block.C2PSA           [256, 256, 1]
#  11                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  12             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  13                  -1  1    111296  ultralytics.nn.modules.block.C3k2            [384, 128, 1, False]
#  14                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  15             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  16                  -1  1     32096  ultralytics.nn.modules.block.C3k2            [256, 64, 1, False]
#  17                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  18            [-1, 13]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  19                  -1  1     86720  ultralytics.nn.modules.block.C3k2            [192, 128, 1, False]
#  20                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  21            [-1, 10]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  22                  -1  1    378880  ultralytics.nn.modules.block.C3k2            [384, 256, 1, True]
#  23        [16, 19, 22]  1    431062  ultralytics.nn.modules.head.Detect           [2, [64, 128, 256]]
# YOLO11n summary: 319 layers, 2,590,230 parameters, 2,590,214 gradients, 6.4 GFLOPs
#
# Transferred 448/499 items from pretrained weights
# Freezing layer 'model.23.dfl.conv.weight'
# train: Scanning /Users/baslad01/data_dump/openfoodfacts/yolo/data/labels/train.cache... 109 images, 0 backgrounds, 4 corrupt: 100%|██████████| 109/109 [00:00<?, ?it/s]
# train: WARNING ⚠️ /Users/baslad01/data_dump/openfoodfacts/yolo/data/images/train/ByJGwB51bp.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.5136]
# train: WARNING ⚠️ /Users/baslad01/data_dump/openfoodfacts/yolo/data/images/train/P4NaXRglAW.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.4813]
# train: WARNING ⚠️ /Users/baslad01/data_dump/openfoodfacts/yolo/data/images/train/XzotST8ZsP.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.1149]
# train: WARNING ⚠️ /Users/baslad01/data_dump/openfoodfacts/yolo/data/images/train/rBklaZOEU6.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.5094]
# val: Scanning /Users/baslad01/data_dump/openfoodfacts/yolo/data/labels/val.cache... 24 images, 0 backgrounds, 0 corrupt: 100%|██████████| 24/24 [00:00<?, ?it/s]
# Plotting labels to /Users/baslad01/data_dump/openfoodfacts/yolo/model/train/labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.001667, momentum=0.9) with parameter groups 81 weight(decay=0.0), 88 weight(decay=0.0005), 87 bias(decay=0.0)
# Image sizes 640 train, 640 val
# Using 0 dataloader workers
# Logging results to /Users/baslad01/data_dump/openfoodfacts/yolo/model/train
# Starting training for 10 epochs...
# Closing dataloader mosaic
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        1/10      5.85G      1.179      3.609      1.125         50        640: 100%|██████████| 7/7 [00:18<00:00,  2.61s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:04<00:00,  4.71s/it]
#                    all         24         81     0.0103      0.519     0.0589     0.0382
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        2/10      5.72G      1.019      2.962      1.007         46        640: 100%|██████████| 7/7 [00:09<00:00,  1.37s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:02<00:00,  2.27s/it]
#                    all         24         81    0.00885      0.457      0.103     0.0759
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        3/10      4.78G      1.174      2.237       1.04         23        640: 100%|██████████| 7/7 [00:08<00:00,  1.28s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:02<00:00,  2.97s/it]
#                    all         24         81       0.01      0.519       0.12     0.0855
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        4/10      5.93G      1.096       1.83      1.041         23        640: 100%|██████████| 7/7 [00:08<00:00,  1.16s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:02<00:00,  2.84s/it]
#                    all         24         81     0.0132      0.679      0.141      0.105
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        5/10      4.65G      1.152      1.585      1.038         38        640: 100%|██████████| 7/7 [00:08<00:00,  1.27s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:02<00:00,  2.89s/it]
#                    all         24         81     0.0157      0.802      0.304      0.233
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        6/10      4.65G      1.079       1.52     0.9975         25        640: 100%|██████████| 7/7 [00:08<00:00,  1.25s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:03<00:00,  3.08s/it]
#                    all         24         81     0.0178      0.914      0.316      0.231
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        7/10      5.93G      1.036      1.427     0.9957         26        640: 100%|██████████| 7/7 [00:09<00:00,  1.36s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:03<00:00,  3.49s/it]
#                    all         24         81     0.0187      0.988      0.457      0.336
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        8/10      5.71G     0.9332      1.403      0.977         34        640: 100%|██████████| 7/7 [00:09<00:00,  1.29s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:03<00:00,  3.26s/it]
#                    all         24         81     0.0185      0.988      0.524      0.386
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        9/10      5.95G     0.9581      1.387     0.9922         40        640: 100%|██████████| 7/7 [00:08<00:00,  1.22s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:03<00:00,  3.23s/it]
#                    all         24         81          1     0.0921       0.62       0.47
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       10/10      4.72G       1.01      1.351     0.9605         61        640: 100%|██████████| 7/7 [00:09<00:00,  1.35s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:03<00:00,  3.53s/it]
#                    all         24         81          1      0.158      0.754       0.57
# 10 epochs completed in 0.038 hours.
# Optimizer stripped from /Users/baslad01/data_dump/openfoodfacts/yolo/model/train/weights/last.pt, 5.5MB
# Optimizer stripped from /Users/baslad01/data_dump/openfoodfacts/yolo/model/train/weights/best.pt, 5.5MB
#
# Validating /Users/baslad01/data_dump/openfoodfacts/yolo/model/train/weights/best.pt...
# Ultralytics 8.3.27 🚀 Python-3.12.7 torch-2.5.1 MPS (Apple M1 Pro)
# YOLO11n summary (fused): 238 layers, 2,582,542 parameters, 0 gradients, 6.3 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:02<00:00,  2.49s/it]
#                    all         24         81          1      0.158      0.755       0.57
#              price-tag         24         81          1      0.158      0.755       0.57
# Speed: 1.9ms preprocess, 22.8ms inference, 0.0ms loss, 12.0ms postprocess per image
# Results saved to /Users/baslad01/data_dump/openfoodfacts/yolo/model/train
# Ultralytics 8.3.27 🚀 Python-3.12.7 torch-2.5.1 MPS (Apple M1 Pro)
# YOLO11n summary (fused): 238 layers, 2,582,542 parameters, 0 gradients, 6.3 GFLOPs
# val: Scanning /Users/baslad01/data_dump/openfoodfacts/yolo/data/labels/val.cache... 24 images, 0 backgrounds, 0 corrupt: 100%|██████████| 24/24 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:05<00:00,  2.94s/it]
#                    all         24         81          1      0.155      0.748      0.564
#              price-tag         24         81          1      0.155      0.748      0.564
# Speed: 2.1ms preprocess, 112.0ms inference, 0.0ms loss, 60.6ms postprocess per image
# Results saved to /Users/baslad01/data_dump/openfoodfacts/yolo/model/train2

# %%
# Perform object detection on an image

image_test_list = [f"{data_path}/test/4xXuBb8u3E.jpg", f"{data_path}/test/test_image.jpg"]

results = model.predict(image_test_list, conf=0.1, save=True, project=f"{data_path}/test")  # or with a list of image paths
# results[0].show()
# Out:
# 0: 640x640 1 price-tag, 26.7ms
# 1: 640x640 (no detections), 26.7ms
# Speed: 3.0ms preprocess, 26.7ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to /Users/baslad01/data_dump/openfoodfacts/yolo/test/train2

# %%
# Export model
path = model.export(format="onnx")
# Out:
# Ultralytics 8.3.27 🚀 Python-3.12.7 torch-2.5.1 CPU (Apple M1 Pro)
#
# PyTorch: starting from '/Users/baslad01/data_dump/openfoodfacts/yolo/model/train/weights/best.pt' with input shape (1, 3, 640, 640) BCHW and output shape(s) (1, 6, 8400) (5.2 MB)
#
# ONNX: starting export with onnx 1.17.0 opset 19...
# ONNX: slimming with onnxslim 0.1.36...
# ONNX: export success ✅ 0.8s, saved as '/Users/baslad01/data_dump/openfoodfacts/yolo/model/train/weights/best.onnx' (10.1 MB)
#
# Export complete (1.0s)
# Results saved to /Users/baslad01/data_dump/openfoodfacts/yolo/model/train/weights
# Predict:         yolo predict task=detect model=/Users/baslad01/data_dump/openfoodfacts/yolo/model/train/weights/best.onnx imgsz=640
# Validate:        yolo val task=detect model=/Users/baslad01/data_dump/openfoodfacts/yolo/model/train/weights/best.onnx imgsz=640 data=/Users/baslad01/data_dump/openfoodfacts/yolo/data.yaml
# Visualize:       https://netron.app
